# %%
#imports
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
def model(t,z,beta,gamma):
    S,I,R=z
    dSdt=-beta*S*I
    dIdt=beta*S*I-gamma*I
    dRdt=gamma*I
    return [dSdt,dIdt,dRdt]

#initial conditions
beta = 0.5
gamma = 1/3
S = 1
I = 1.27 * 10**(-6)
R = 0
z0 = [S,I,R]
t_span = (0,200)
t_eval = np.linspace(*t_span,1000)

#solve ODE
sol = solve_ivp(model,t_span,z0,args=(beta,gamma),t_eval=t_eval)
print(sol)
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  2.002e-01 ...  1.998e+02  2.000e+02]
#         y: [[ 1.000e+00  1.000e+00 ...  4.179e-01  4.179e-01]
#             [ 1.270e-06  1.313e-06 ...  8.820e-08  8.616e-08]
#             [ 0.000e+00  8.618e-08 ...  5.821e-01  5.821e-01]]
#       sol: None
#  t_events: None
#  y_events: None
#      nfev: 140
#      njev: 0
#       nlu: 0

# %%
#plots
plt.plot(sol.t,sol.y[0],label='S')
plt.plot(sol.t,sol.y[1],label='I')
plt.plot(sol.t,sol.y[2],label='R')
plt.legend()
plt.grid()
plt.show()
